# %% [markdown]
# # OYANIYI  DAMILOLA  AKINJIDE
# # EEG/2019/071

# %% [markdown]
# # DIY 1

# %%
# Trying to see how powerful the enumerative method is 
## by testing how large a number i could be before a pause in 
## printing can be noticed

max_val = int(input('Enter a positive integer:'))
i = 0
while i < max_val:
    i = i + 1
print(i)

import time

start_time = time.perf_counter() # Start the timer
end_time = time.perf_counter() # End the timer
elapsed_time = end_time - start_time # Calculate the elapsed time

print(f"Elapsed time: {elapsed_time:.6f} seconds")
# Out:
# Enter a positive integer:10000000
# 10000000
# Elapsed time: 0.000047 seconds

# %% [markdown]
# # DIY 2

# %%
## Test if an int > 2 is prime. If not, print largest divisor
x = int(input('Enter an integer greater then 2:'))
smallest_divisor = None
for guess in range(2,x):
    if x%guess == 0:
        smallest_divisor = guess
        largest_divisor = x/smallest_divisor
        break
if smallest_divisor != None:
    print('Largest divisor of', x, 'is', largest_divisor)
else:
    print(x, 'is a prime number')
# Out:
# Enter an integer greater then 2:101
# 101 is a prime number

# %% [markdown]
# # DIY 3

# %%
def prime(num): # Function to check if a number is prime
    if num < 2:
        return True
    for i in range(3, int(num**0.5) + 1, 2):
        if num % i == 0:
            return False
    return True
sum_of_prime = 0
for num in range(3,1000,2):
    if prime(num):
        sum_of_prime += num
print("The sum of prime number greater than 2 and less than 1000 is:", sum_of_prime)
# Out:
# The sum of prime number greater than 2 and less than 1000 is: 76125

# %% [markdown]
# # DIY 4

# %%
x = 123456 # Let's try to use more educated guesses
## knowing by constantly trying to find the middle we can
## get closer to the square faster,
## checkout the number of tries 30 instead of 3513631 (a 120,000 times improvement) !!)
epsilon = 0.01
num_guesses, low = 0,0
high = max(1,x)
ans = (high + low)/2
while abs(ans**2 - x) >= epsilon:
    print('low =', low, 'high = ', high, 'ans =', ans)
    num_guesses += 1
    if ans**2 < x:
        low = ans
    else:
        high = ans
    ans = (high + low)/2
print('number of guesses =', num_guesses)
print(ans, 'is close to square root of', x)

import matplotlib.pyplot as plt
# For x = 1,12,123,1234,12345,123456

x_values = [1,2,3,4,5,6]
y_values = [7,10,15,21,26,30]
print(x_values)
print(y_values)

plt.plot(x_values, y_values)

plt.xlabel("Digits")
plt.ylabel("Guesses")
plt.title("Number of digits vs. Number of guesses for different numbers")
plt.show()
# Out:
# low = 0 high =  123456 ans = 61728.0
# low = 0 high =  61728.0 ans = 30864.0
# low = 0 high =  30864.0 ans = 15432.0
# low = 0 high =  15432.0 ans = 7716.0
# low = 0 high =  7716.0 ans = 3858.0
# low = 0 high =  3858.0 ans = 1929.0
# low = 0 high =  1929.0 ans = 964.5
# low = 0 high =  964.5 ans = 482.25
# low = 0 high =  482.25 ans = 241.125
# low = 241.125 high =  482.25 ans = 361.6875
# low = 241.125 high =  361.6875 ans = 301.40625
# low = 301.40625 high =  361.6875 ans = 331.546875
# low = 331.546875 high =  361.6875 ans = 346.6171875
# low = 346.6171875 high =  361.6875 ans = 354.15234375
# low = 346.6171875 high =  354.15234375 ans = 350.384765625
# low = 350.384765625 high =  354.15234375 ans = 352.2685546875
# low = 350.384765625 high =  352.2685546875 ans = 351.32666015625
# low = 351.32666015625 high =  352.2685546875 ans = 351.797607421875
# low = 351.32666015625 high =  351.797607421875 ans = 351.5621337890625
# ...

# %% [markdown]
# # DIY 5

# %%
import math
def find_product_by_log_sum(num_1, num_2):
    
    num_1 = int(input("Enter the first number:"))
    num_2 = int(input("Enter the second number:"))
    
    log_sum = math.log10(num_1) + math.log10(num_2) # Sum the log of two numbers
    antilog = 10 ** log_sum # Finding the antilog of the sum)
    
    print("The product of", num_1, "and", num_2, "is:", log_sum)
    print(f"antilog is {antilog}")
    
    return antilog
   
product = find_product_by_log_sum(num_1,num_2)
# Out:
# Enter the first number:10
# Enter the second number:100
# The product of 10 and 100 is: 3.0
# antilog is 1000.0

# %% [markdown]
# # DIY 6

# %%
gain = float(input("Enter the gain value:"))  # Get the value of gain
dB = 20 * math.log10(gain)  # Calculate the decibel (dB) value

print("The gain in decibels (dB) is:", dB)
# Out:
# Enter the gain value:100
# The gain in decibels (dB) is: 40.0
